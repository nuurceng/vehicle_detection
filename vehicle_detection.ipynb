# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Sistem Özellikleri

# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.6 LTS"

# %% [markdown]
# Depolama Alanı Güncelleme

# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# ...

# %% [markdown]
# Adres Öğrenme

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# Zipten Çıkarma

# %%
# !unzip "/content/drive/MyDrive/vehicle/darknet.zip"
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   inflating: darknet/yv_data/labels/Highway_311_2020-07-30_jpg.rf.28d5cf2aede5dcd26a5fe41bea3618df.txt
#   inflating: darknet/yv_data/labels/Highway_311_2020-07-30_jpg.rf.9cb6ef41a1b7eca9dfb9e95e11011286.txt
#   inflating: darknet/yv_data/labels/highway_3110_2020-08-26.txt
#   inflating: darknet/yv_data/labels/highway_3111_2020-08-26.txt
#   inflating: darknet/yv_data/labels/highway_3112_2020-08-26.txt
#   inflating: darknet/yv_data/labels/highway_3113_2020-08-26.txt
#   inflating: darknet/yv_data/labels/highway_3114_2020-08-26.txt
#   inflating: darknet/yv_data/labels/highway_3115_2020-08-26.txt
#   inflating: darknet/yv_data/labels/highway_3116_2020-08-26.txt
#   inflating: darknet/yv_data/labels/highway_3117_2020-08-26.txt
#   inflating: darknet/yv_data/labels/highway_3118_2020-08-26.txt
#   inflating: darknet/yv_data/labels/highway_3119_2020-08-26.txt
# ...

# %% [markdown]
# Adres Ayarlama

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %% [markdown]
# Dos2unix İndirme

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (327 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %% [markdown]
# Dosyaları unixe Çevirme

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./yv_data/images/ulu1810_jpg.rf.1704ff6e32a55934d189a439517d97e3.jpg
# dos2unix: converting file ./yv_data/images/ulu1810_jpg.rf.1704ff6e32a55934d189a439517d97e3.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./yv_data/images/ulu1811_jpg.rf.ef49317c2a20b03882b0ee984cc7d26d.jpg
# dos2unix: converting file ./yv_data/images/ulu1811_jpg.rf.ef49317c2a20b03882b0ee984cc7d26d.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./yv_data/images/ulu1812_jpg.rf.5f980b94a2e9972f57b3950ae6193980.jpg
# dos2unix: converting file ./yv_data/images/ulu1812_jpg.rf.5f980b94a2e9972f57b3950ae6193980.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./yv_data/images/ulu1813_jpg.rf.9263b1dd74d362107a578d81df43192a.jpg
# ...

# %% [markdown]
# İzin

# %%
# !chmod +x /content/darknet

# %% [markdown]
# Çalıştırma

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# Darknet Testi

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/dog.jpg
# Out:
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %% [markdown]
# Dosya Silme

# %%
# !rm /content/darknet/backup -r

# %% [markdown]
# Drive Backup Bağlantısı

# %%
# !ln -s /content/drive/"My Drive"/vehicle/backup /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %% [markdown]
# Eğitime Başlama

# %%
# !./darknet detector train yv_data/vehicle.data vehicle_yolov4.cfg yolov4.conv.137 -map -dont_show
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.769688), count: 1, class_loss = 0.878265, iou_loss = 0.204725, total_loss = 1.082990
#  total_bbox = 1689749, rewritten_bbox = 0.385205 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.579034), count: 4, class_loss = 5.713766, iou_loss = 18.501104, total_loss = 24.214870
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.740354), count: 3, class_loss = 2.298303, iou_loss = 3.188318, total_loss = 5.486621
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.676293), count: 1, class_loss = 0.770211, iou_loss = 1.076987, total_loss = 1.847198
#  total_bbox = 1689757, rewritten_bbox = 0.385203 %
# ...
